# %% [markdown]
# ## Object Oriented Method
#
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y, 'b')
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# ### One plot in another

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # Main Plot
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # Inner Plot

axes1.plot(x, y, 'r')
axes1.set_xlabel('X Axes 1 Label')
axes1.set_ylabel('Y Axes 1 Label')
axes1.set_title('Main Plot')

axes2.plot(y, x, 'b')
axes2.set_xlabel('X Axes 2 Label')
axes2.set_ylabel('Y Axes 2 Label')
axes2.set_title('Inner Plot')
# Out:
# Text(0.5,1,'Inner Plot')

# %% [markdown]
# ### Subplots
#
# The <code>plt.subplots()</code> object will act as a more automatic axis manager.

# %%
fig, axes = plt.subplots()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1146afa20>,
# ...
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x, y)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Title')
    
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_title('First Plot')

axes[1].plot(y, x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5,1,'Second Plot')

# %% [markdown]
# A common issue with matplolib is overlapping subplots or figures. We ca use fig.tight_layout() or plt.tight_layout() method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_title('First Plot')

axes[1].plot(y, x)
axes[1].set_title('Second Plot')

plt.tight_layout()
